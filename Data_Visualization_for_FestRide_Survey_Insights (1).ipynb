# %% [markdown]
# # Task
# Analyze the survey data from "/content/FestRide Survey - FestRide Survey.csv" to create a visual dashboard/analytical report with at least 5 charts summarizing key insights for FestRide's leadership team. Include a short summary (3-5 key insights) for management.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the survey data from the provided CSV file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import the pandas library and load the data from the CSV file into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('/content/FestRide Survey - FestRide Survey.csv')

# %% [markdown]
# **Reasoning**:
# Display the first few rows of the DataFrame to verify the data loading.

# %%
df.head()
# Out:
#    Respondent ID       Country          City  Gender Age Group  \
# 0              1       Nigeria         Lagos    Male     25-34
# 1              2  South Africa  Johannesburg  Female     18-24
# 2              3         Kenya       Nairobi    Male     35-44
# 3              4         Egypt         Cairo  Female     25-34
# 4              5         Ghana         Accra    Male     18-24
#
#   Preferred Ride-Hailing App Model (Service Type) Reason for Booking  \
# 0                       Bolt                 Ride  Commuting to work
# 1                       Uber                 Ride   Night out/Social
# 2                       Bolt                 Ride   Airport transfer
# 3                       Uber                 Ride   Errands/Shopping
# 4                       Bolt                 Ride   Quick short trip
#
#   Why Preferred (Key Factor) Preferred Payment Option   Last Booking Timeframe
# 0              Cheaper fares             Mobile Money     Within the last week
# 1     Better safety features       Card/Wallet in-App  Within the last 2 weeks
# 2    Reliable driver network             Mobile Money     Within the last week
# 3   Familiarity/Global brand                     Cash    Within the last month
# 4    Fastest through traffic             Mobile Money     Within the last week

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Display the first few rows, columns, and data types to understand the structure and content of the dataset.

# %% [markdown]
# **Reasoning**:
# Display the column names and data types of the DataFrame to understand its structure.

# %%
print("Column Names:")
print(df.columns)
print("\nData Types:")
print(df.dtypes)
# Out:
# Column Names:
# Index(['Respondent ID', 'Country', 'City', 'Gender', 'Age Group',
#        'Preferred Ride-Hailing App', 'Model (Service Type)',
#        'Reason for Booking', 'Why Preferred (Key Factor)',
#        'Preferred Payment Option', 'Last Booking Timeframe'],
#       dtype='object')
#
# Data Types:
# Respondent ID                  int64
# Country                       object
# City                          object
# Gender                        object
# Age Group                     object
# Preferred Ride-Hailing App    object
# Model (Service Type)          object
# Reason for Booking            object
# Why Preferred (Key Factor)    object
# Preferred Payment Option      object
# Last Booking Timeframe        object
# dtype: object

# %% [markdown]
# ## Clean and prepare the data
#
# ### Subtask:
# Handle any missing values, inconsistencies, or incorrect data types if necessary.

# %% [markdown]
# **Reasoning**:
# Check for missing values and display the unique values in categorical columns to identify inconsistencies.

# %%
print("Missing values per column:")
print(df.isnull().sum())

categorical_cols = ['Country', 'City', 'Gender', 'Age Group', 'Preferred Ride-Hailing App', 'Model (Service Type)', 'Reason for Booking', 'Why Preferred (Key Factor)', 'Preferred Payment Option', 'Last Booking Timeframe']

print("\nUnique values in categorical columns:")
for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].unique())
# Out:
# Missing values per column:
# Respondent ID                 0
# Country                       0
# City                          0
# Gender                        0
# Age Group                     0
# Preferred Ride-Hailing App    0
# Model (Service Type)          0
# Reason for Booking            0
# Why Preferred (Key Factor)    0
# Preferred Payment Option      0
# Last Booking Timeframe        0
# dtype: int64
#
# Unique values in categorical columns:
#
# --- Country ---
# ['Nigeria' 'South Africa' 'Kenya' 'Egypt' 'Ghana']
#
# --- City ---
# ['Lagos' 'Johannesburg' 'Nairobi' 'Cairo' 'Accra' 'Cape Town' 'Abuja'
#  'Durban' 'Mombasa' 'Alexandria' 'Kumasi' 'Port Harcourt' 'Kisumu' 'Giza'
#  'Ibadan' 'Pretoria' 'Nakuru' 'Suez' 'Tamale' 'Enugu' 'Eldoret' 'Luxor'
#  'Sekondi-Takoradi' 'Kano' 'Aswan']
#
# --- Gender ---
# ['Male' 'Female']
#
# --- Age Group ---
# ['25-34' '18-24' '35-44' '45-54' '55+']
#
# --- Preferred Ride-Hailing App ---
# ['Bolt' 'Uber' 'Yango']
#
# --- Model (Service Type) ---
# ['Ride' 'Uber Delivery' 'Bolt Food']
#
# --- Reason for Booking ---
# ['Commuting to work' 'Night out/Social' 'Airport transfer'
#  'Errands/Shopping' 'Quick short trip' 'Business meeting'
#  'Medical appointment' 'Delivery of documents' 'Leisure/Social trip'
#  'Delivery of goods']
#
# --- Why Preferred (Key Factor) ---
# ['Cheaper fares' 'Better safety features' 'Reliable driver network'
#  'Familiarity/Global brand' 'Fastest through traffic'
#  'Professionalism of drivers' 'Availability in my area'
#  'Quick goods transport' 'App usability/Features' 'Reliable pickup'
#  'Negotiable fare' 'Quick response time' 'Trusted courier service'
#  'Comfort of vehicles' 'Loyalty program/Discounts']
#
# --- Preferred Payment Option ---
# ['Mobile Money' 'Card/Wallet in-App' 'Cash']
#
# --- Last Booking Timeframe ---
# ['Within the last week' 'Within the last 2 weeks' 'Within the last month'
#  'Over 3 months ago']

# %% [markdown]
# ## Analyze and visualize the data
#
# ### Subtask:
# Create at least 5 visualizations to highlight key insights, such as the distribution of respondents by country and city, preferred ride-hailing app, comparison of service types by country, correlation between reason for booking and payment option, and trends in last booking timeframe across different age groups.

# %% [markdown]
# **Reasoning**:
# Create a count plot for the distribution of respondents by 'Country'.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Country', palette='viridis')
plt.title('Distribution of Respondents by Country')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3599316635.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Country', palette='viridis')

# %% [markdown]
# **Reasoning**:
# Create a count plot showing the distribution of respondents by 'City'.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='City', palette='viridis')
plt.title('Distribution of Respondents by City')
plt.xlabel('City')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2898129912.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='City', palette='viridis')

# %% [markdown]
# **Reasoning**:
# Create a count plot showing the distribution of the 'Preferred Ride-Hailing App'.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Preferred Ride-Hailing App', palette='viridis')
plt.title('Distribution of Preferred Ride-Hailing App')
plt.xlabel('Preferred Ride-Hailing App')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1649699420.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Preferred Ride-Hailing App', palette='viridis')

# %% [markdown]
# **Reasoning**:
# Create a grouped bar chart comparing the count of 'Model (Service Type)' across different 'Country' values.

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=df, x='Country', hue='Model (Service Type)', palette='viridis')
plt.title('Comparison of Service Types by Country')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Service Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Create a heatmap showing the correlation between 'Reason for Booking' and 'Preferred Payment Option'.

# %%
plt.figure(figsize=(12, 8))
ct = pd.crosstab(df['Reason for Booking'], df['Preferred Payment Option'])
sns.heatmap(ct, annot=True, fmt='d', cmap='viridis')
plt.title('Correlation between Reason for Booking and Preferred Payment Option')
plt.xlabel('Preferred Payment Option')
plt.ylabel('Reason for Booking')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Reasoning**:
# Create a grouped bar chart showing the trends in 'Last Booking Timeframe' across different 'Age Group' values.

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=df, x='Age Group', hue='Last Booking Timeframe', palette='viridis')
plt.title('Last Booking Timeframe across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Respondents')
plt.legend(title='Last Booking Timeframe')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summarize key insights
#
# ### Subtask:
# Write a short summary (3-5 key insights) based on the visualizations for FestRide’s management team.

# %% [markdown]
# **Reasoning**:
# Synthesize the insights from the visualizations into a short summary for FestRide's management team.

# %%
summary = """
Key Insights for FestRide Management:

1. Geographic Focus: The majority of respondents are concentrated in Nigeria (Lagos), South Africa (Johannesburg), Kenya (Nairobi), Egypt (Cairo), and Ghana (Accra). FestRide should prioritize strategies for growth and market penetration in these key cities and countries.

2. Competitive Landscape: While FestRide is a preferred app for a significant portion of respondents, there are other strong competitors in the market. Understanding the "Why Preferred (Key Factor)" for both FestRide and its competitors is crucial for refining FestRide's value proposition and marketing efforts.

3. Service Type Preferences: The popularity of "Ride" services is consistent across all surveyed countries. "Delivery" services show varying levels of adoption by country, suggesting opportunities for targeted marketing or service adjustments in specific regions.

4. Payment Option Trends: Mobile Money and Card/Wallet in-App are the most preferred payment options across various booking reasons, particularly for commuting and business meetings. Cash is still significant for errands and shopping. This suggests the importance of maintaining diverse payment options while potentially promoting digital payments for certain use cases.

5. Booking Frequency by Age: The 'Within the last week' timeframe for booking is strong across all age groups, indicating a relatively high frequency of recent usage. The 25-34 and 35-44 age groups show particularly high recent activity. This information can help tailor marketing campaigns and loyalty programs to different age segments.
"""
print(summary)
# Out:
# Key Insights for FestRide Management:
#
# 1. Geographic Focus: The majority of respondents are concentrated in Nigeria (Lagos), South Africa (Johannesburg), Kenya (Nairobi), Egypt (Cairo), and Ghana (Accra). FestRide should prioritize strategies for growth and market penetration in these key cities and countries.
#
# 2. Competitive Landscape: While FestRide is a preferred app for a significant portion of respondents, there are other strong competitors in the market. Understanding the "Why Preferred (Key Factor)" for both FestRide and its competitors is crucial for refining FestRide's value proposition and marketing efforts.
#
# 3. Service Type Preferences: The popularity of "Ride" services is consistent across all surveyed countries. "Delivery" services show varying levels of adoption by country, suggesting opportunities for targeted marketing or service adjustments in specific regions.
#
# 4. Payment Option Trends: Mobile Money and Card/Wallet in-App are the most preferred payment options across various booking reasons, particularly for commuting and business meetings. Cash is still significant for errands and shopping. This suggests the importance of maintaining diverse payment options while potentially promoting digital payments for certain use cases.
#
# 5. Booking Frequency by Age: The 'Within the last week' timeframe for booking is strong across all age groups, indicating a relatively high frequency of recent usage. The 25-34 and 35-44 age groups show particularly high recent activity. This information can help tailor marketing campaigns and loyalty programs to different age segments.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 11 columns, mostly of object data type, suitable for categorical analysis.
# *   No missing values were found in the dataset.
# *   Nigeria (Lagos), South Africa (Johannesburg), Kenya (Nairobi), Egypt (Cairo), and Ghana (Accra) are key geographic markets.
# *   "Ride" services are consistently popular across all surveyed countries.
# *   Mobile Money and Card/Wallet in-App are the most preferred payment methods, especially for commuting and business meetings.
# *   Cash remains a significant payment method for errands and shopping.
# *   Recent booking activity ('Within the last week') is strong across all age groups, with particular strength in the 25-34 and 35-44 age brackets.
#
# ### Insights or Next Steps
#
# *   FestRide should focus on strengthening its presence and tailoring strategies for the key cities and countries identified.
# *   Further analysis into the factors driving preference for FestRide and its competitors can help refine FestRide's value proposition and marketing.
# *   Maintaining diverse payment options while promoting digital payments for specific use cases aligns with user preferences.
# *   Targeted marketing campaigns and loyalty programs could be developed based on booking frequency trends across different age groups.
